# %%
"Part 1"
"For the first part we will need to clean the data and put it into a standard form. (You can choose the standard form.) To do this you will need to write a python script that loads a specific file downloaded from the Discussions board. "
#import merged data
from google.colab import files
uploaded = files.upload()

# read data
with open('output_Webscrap_HW2.txt', 'r') as d:
    data1 = d.read()
with open('name_purpose.txt', 'r') as d:
    data1 = d.read()
with open('foryou4.txt', 'r') as d:
    data1 = d.read()
with open('595_HW2.txt', 'r') as d:
    data1 = d.read()
with open('companies.txt', 'r') as d:
    data1 = d.read()
with open('result.txt', 'r') as d:
    data1 = d.read()
with open('result.csv', 'r') as d:
    data1 = d.read()
with open('napu.csv', 'r') as d:
    data1 = d.read()
with open('companys.csv', 'r') as d:
    data1 = d.read()
with open('ListOfCompanies JVansant.csv', 'r') as d:
    data1 = d.read()
# Out:
#      <input type="file" id="files-8185e029-f490-4222-8e0c-fef52ba9556c" name="files[]" multiple disabled />
#      <output id="result-8185e029-f490-4222-8e0c-fef52ba9556c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving merged data.txt to merged data (5).txt
# Saving output_Webscrap_HW2.txt to output_Webscrap_HW2.txt
# Saving merged data.csv to merged data (2).csv
# Saving name_purpose.txt to name_purpose.txt
# Saving foryou4.txt to foryou4.txt
# Saving 595_HW2.txt to 595_HW2.txt
# Saving companies.txt to companies.txt
# Saving result.txt to result.txt
# Saving result.csv to result.csv
# Saving napu.csv to napu.csv
# Saving companys.csv to companys.csv
# Saving ListOfCompanies JVansant.csv to ListOfCompanies JVansant.csv

# %%
"Part 2"
"For the second part you will need to provide a script which loads the merged file and sorts the companies from best to worst in terms of sentiment of their purpose."

#import merged data
from google.colab import files
uploaded = files.upload()

import pandas as pd
# read data
with open('merged data.txt', 'r') as d:
    mydata = d.read()
# Out:
#      <input type="file" id="files-1bad6585-74a3-4a1a-bfe4-71bf6c2de619" name="files[]" multiple disabled />
#      <output id="result-1bad6585-74a3-4a1a-bfe4-71bf6c2de619">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving merged data.txt to merged data (4).txt

# %%
# use textblob to rate the sentiment
! pip install textblob
import nltk
from  textblob import TextBlob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.6/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.6/dist-packages (from textblob) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk>=3.1->textblob) (1.12.0)

# %%
# sort the companies according to their sentiments
d_sentiment = []
d_sen = mydata.splitlines()
for i in range(len(d_sen)):
    d = TextBlob(d_sen[i])
    d_sentiment.append((i, d.sentiment[0]))

sorted_d = sorted(d_sentiment, key=lambda x: x[1], reverse=True)

# %%
#print the companies from top to bottom
top_company = []

for i in range(500):
    top_company.append(d_sen[sorted_d[i][0]])

with open("company rank.txt", 'w') as f:
    for i in top_company:
        print(i)
        f.write(i + '\n')
# Out:
# "Wade, Peck and Rose"	Expanded reciprocal matrices for iterate web-enabled mindshare
# Hill-Martin	Proactive needs-based initiative for cultivate sexy paradigms
# Brooks-Reynolds	Innovative full-range structure for incubate extensible markets
# "Le, Chan and Coleman"	Ergonomic asynchronous alliance for cultivate sexy portals
# Smith-Curtis	Cloned contextually-based extranet for reinvent innovative web services
# Gates Inc	 Realigned static model for reinvent frictionless channels
# Shaw-Simmons	 User-friendly discrete toolset for implement innovative networks
# Stokes and Sons	Mandatory motivating complexity for re-contextualize sexy platforms
# Martin-Thomas	Horizontal coherent product for generate best-of-breed markets
# Horton-Carter	Progressive static toolset for engage clicks-and-mortar systems
# "Lucas, Brown and Adkins"	Future-proofed coherent Graphical User Interface for repurpose strategic deliverables
# Riddle LLC	Innovative full-range time-frame for orchestrate web-enabled users
#  Prince-Johnson	 Realigned static support for mesh e-business solutions
#  Mcclure Inc	 Enhanced coherent moderator for enable next-generation e-services
#  Gardner-Martin'	Persevering impactful frame for architect innovative metrics'
#  Jones Ltd'	('User-friendly static customer loyalty for leverage revolutionary ' 'functionalities')
#  Wallace LLC'	Innovative client-server alliance for target distributed solutions'
# Ray Group	Advanced mission-critical help-desk for reinvent one-to-one technologies
#  Mendoza Ltd	 Advanced 3rdgeneration benchmark for drive real-time interfaces
# " Bowman, Jones and Davis"	 Realigned coherent success for redefine magnetic e-markets
#  Pacheco-Adams'	('Advanced regional complexity for disintermediate open-source ' 'e-services')
#  Tran-Burns'	Advanced tertiary hierarchy for redefine web-enabled bandwidth'
# " Castro-Carlson,"	Advanced intermediate solution for harness B2B supply-chains
# "Carroll, Mann and Weeks"	Self-enabling hybrid service-desk for seize rich platforms
#  Reynolds and Sons	 Up-sized multimedia adapter for integrate rich experiences
#  Owen PLC	 Adaptive non-volatile definition for iterate rich supply-chains
# " Kelley, Mccarty and Padilla"	 Organized fault-tolerant encryption for reinvent rich interfaces
# " Downs, Knapp and Tapia'"	Future-proofed value-added forecast for mesh rich users'
#  Nelson Group'	('Configurable 3rdgeneration superstructure for incentivize rich ' 'channels')
# "Robertson, Powell and Wise"	 Phased 6thgeneration hierarchy for engage dynamic convergence
#  Allen-Casey'	Advanced context-sensitive portal for architect compelling platforms'
# Phillips Group	Networked incremental hub for architect compelling communities
# Lambert-Cook	Triple-buffered even-keeled ability for synthesize compelling vortals
# Barajas LLC	Exclusive human-resource success for envisioneer robust technologies
# "Thompson, Caldwell and Molina"	Centralized tertiary firmware for maximize compelling niches
# Wood PLC	Vision-oriented tertiary instruction set for streamline compelling ROI
#  Marshall-Walton'	('Adaptive interactive architecture for syndicate compelling ' 'communities')
#  Roberts-Huff'	Networked dedicated success for synthesize turn-key communities'
# " Garcia, Morrison and Rios'"	Distributed composite methodology for maximize compelling ROI'
# Blackburn-Adams	Profound coherent customer loyalty for unleash 24/365 bandwidth
# "Robinson, Reed and Ashley"	Profit-focused even-keeled open architecture for harness innovative metrics
# Skinner Ltd	Networked coherent firmware for implement dynamic supply-chains
# "Obrien, Munoz and Jenkins"	Cross-group next generation implementation for synthesize sexy partnerships
# " Ellison, Henderson and Burns"	 Devolved logistical open architecture for incentivize innovative info-mediaries
# "Schwartz, Neal and Garcia"	Advanced impactful Local Area Network for enhance one-to-one functionalities
#  Turner and Sons'	Advanced clear-thinking conglomeration for harness dynamic portals'
#  Stark Ltd	 Innovative demand-driven challenge for streamline sticky niches
# " Smith, Bates and Yates,"	Universal tertiary utilization for revolutionize compelling markets
# "Kramer, Barber and Carpenter"	Sharable intermediate process improvement for synergize seamless metrics
# Carlson-Carpenter	 Configurable explicit architecture for optimize seamless info-mediaries
# Garcia and Sons	 Profit-focused encompassing infrastructure for grow seamless e-tailers
# "Harris, Young and Burns"	 Inverse stable interface for facilitate leading-edge e-business
# Holmes-Jacobs	Cloned demand-driven Internet solution for engineer seamless initiatives
# "Haynes, Young and Patel"	Progressive background middleware for innovate cross-media niches
#  Medina-Dorsey	 Seamless interactive concept for aggregate killer e-markets
#  Lynn-Alvarado	 Front-line high-level toolset for leverage seamless portals
#  Jones Group	 Seamless system-worthy process improvement for orchestrate B2B metrics
# " Dickerson, Henry and Estrada"	 Seamless homogeneous parallelism for disintermediate B2B paradigms
#  Garcia Group'	Seamless directional hub for streamline leading-edge portals'
# " Rivas, Young and Davis,"	Compatible 4thgeneration ability for transform next-generation e-tailers
# Parker-Martinez	Profound background data-warehouse for harness value-added deliverables
# Conway-Massey	Profound homogeneous parallelism for redefine extensible users
# Hicks LLC	Profound tertiary encryption for synergize out-of-the-box portals
#  Zuniga-Foster	 Profound methodical adapter for enhance user-centric methodologies
# Bruce Group	Organized 3rdgeneration migration for deploy leading-edge portals
# Dunn LLC	Implemented mission-critical function for extend front-end niches
# Harper-Boone	Open-source fault-tolerant knowledge user for embrace clicks-and-mortar e-services
# "Cabrera, Levine and Underwood"	Proactive analyzing Internet solution for engage web-enabled e-business
# "Anderson, Stevens and Jensen"	Pre-emptive high-level extranet for enhance value-added platforms
# Roberts Ltd	Extended mission-critical intranet for matrix cross-media paradigms
# Huerta and Sons	Intuitive discrete contingency for repurpose synergistic schemas
# "Jackson, Holden and Gonzalez"	Intuitive eco-centric productivity for iterate dot-com action-items
# Roberts and Sons	Sharable 4thgeneration open system for transform cross-platform e-tailers
# Simpson and Sons	Ameliorated encompassing website for expedite proactive platforms
# Davidson Ltd	Object-based non-volatile protocol for deliver clicks-and-mortar e-services
# "Vaughan, Calderon and Holland"	Distributed maximized portal for cultivate cross-media convergence
# Williamson-Johnson	Versatile upward-trending task-force for disintermediate clicks-and-mortar e-markets
# Washington-Mccormick	Intuitive demand-driven project for deploy killer models
# "Moore, Mcintyre and Campbell"	Intuitive 24hour algorithm for drive out-of-the-box networks
# Davis-Meyers	Public-key client-driven orchestration for engineer synergistic interfaces
# Smith PLC	Open-source grid-enabled contingency for target enterprise info-mediaries
# "Olson, Murray and Johnson"	Synergistic 3rdgeneration extranet for repurpose 24/365 communities
# Sullivan and Sons	User-centric mobile architecture for grow next-generation systems
# Lopez-Russo	Future-proofed multimedia approach for scale revolutionary models
# "Flores, Moore and Powell"	Distributed radical structure for transition cross-media applications
# "Gordon, Smith and Evans"	User-friendly heuristic customer loyalty for implement bleeding-edge e-services
# Goodwin PLC	Enhanced methodical info-mediaries for re-intermediate strategic web-readiness
# Spence PLC	Monitored client-server system engine for mesh 24/7 ROI
# Doyle-Foley	Persistent maximized portal for morph 24/7 communities
# Edwards Ltd	Reduced methodical hierarchy for target bricks-and-clicks e-markets
# Brown-Ross	De-engineered systemic open system for engage distributed info-mediaries
# Bauer Ltd	Cross-platform uniform archive for aggregate plug-and-play bandwidth
# Johnson Ltd	Customer-focused logistical complexity for synergize customized portals
# Weeks-Glass	Synchronized 4thgeneration collaboration for envisioneer distributed metrics
# Powell-Hamilton	Enterprise-wide motivating circuit for reinvent proactive markets
# "White, Lewis and Chambers"	Synergized web-enabled utilization for syndicate transparent partnerships
# Juarez and Sons	Enterprise-wide non-volatile emulation for maximize robust vortals
# Davis Group	Open-architected eco-centric knowledgebase for integrate virtual communities
# Savage-Jones	Customer-focused even-keeled encryption for engage cross-platform e-markets
# "Hill, Robbins and Cruz"	Virtual contextually-based info-mediaries for iterate 24/365 info-mediaries
# "Burke, Prince and Sanders"	Synergized national protocol for architect next-generation convergence
# "Logan, Thomas and Calhoun"	Mandatory tangible intranet for productize global experiences
# Coleman-Espinoza	Visionary human-resource capability for revolutionize turn-key interfaces
# Patel Ltd	Profit-focused executive moderator for redefine magnetic deliverables
# "Reynolds, Bell and Russell"	Centralized clear-thinking portal for syndicate best-of-breed vortals
# Brown Group	Object-based maximized groupware for deliver bricks-and-clicks niches
# Wiggins-Wright	Intuitive incremental implementation for synergize dynamic functionalities
# "Jenkins, Perez and Carrillo"	Automated empowering knowledge user for integrate frictionless communities
# "Montoya, Camacho and Harrison"	Compatible bottom-line structure for grow vertical e-services
# Walker Group	Self-enabling asynchronous encryption for embrace revolutionary functionalities
# Maldonado-Curtis	Switchable background customer loyalty for whiteboard impactful eyeballs
# "Smith, Richardson and Wright"	Devolved homogeneous projection for embrace integrated e-commerce
# Cruz-Powell	De-engineered 5thgeneration database for morph proactive platforms
# Massey-Atkinson	Ameliorated systematic database for expedite value-added e-commerce
# Yu-Mckenzie	Ergonomic asynchronous interface for facilitate leading-edge partnerships
# Knight Inc	Fundamental global help-desk for integrate web-enabled infrastructures
# Carroll Group	Horizontal national capability for extend bricks-and-clicks platforms
# Hill PLC	Self-enabling global firmware for synergize web-enabled eyeballs
# "Mcclain, Mccarthy and Lozano"	Upgradable clear-thinking data-warehouse for drive killer convergence
# Powell Ltd	Enterprise-wide intangible contingency for extend frictionless infrastructures
# "Huffman, Norton and Cantu"	Cloned client-driven system engine for envisioneer killer mindshare
# Schmidt-Brown	Open-architected grid-enabled projection for deploy next-generation content
# Hanna Group	Team-oriented grid-enabled workforce for enhance magnetic applications
# Walter PLC	Fundamental explicit extranet for enable integrated action-items
# Smith-Farmer	Up-sized object-oriented utilization for exploit frictionless initiatives
# Levy-Garrison	Proactive multi-tasking approach for mesh next-generation vortals
# "Vance, Michael and Stafford"	Triple-buffered transitional encoding for grow impactful initiatives
# Ball LLC	Exclusive intangible Graphic Interface for target back-end methodologies
# Landry-Schmidt	Inverse content-based process improvement for envisioneer plug-and-play models
# Farley Group	Ergonomic dedicated function for scale customized action-items
# Hicks-Lewis	Persistent zero tolerance synergy for productize distributed models
# King-Washington	Reverse-engineered mobile middleware for expedite cross-media vortals
# Castillo PLC	Vision-oriented well-modulated capacity for leverage world-class web services
# Le-Brock	Team-oriented clear-thinking productivity for grow value-added e-services
# Orr-Pierce	Polarized dedicated encoding for strategize plug-and-play methodologies
# Decker-Grant	Customizable high-level encryption for engineer open-source partnerships
# Coleman-Lopez	Managed composite structure for implement out-of-the-box models
# "Harrison, Garcia and Patterson"	Cross-platform global methodology for visualize ubiquitous convergence
# Schwartz PLC	Polarized high-level software for morph strategic deliverables
# Pope and Sons	Horizontal asymmetric Local Area Network for seize sticky bandwidth
# "Anderson, Smith and Cox"	Multi-tiered even-keeled matrix for synthesize back-end platforms
# Morgan Inc	Self-enabling tangible migration for repurpose bleeding-edge portals
# Larson-Steele	Enhanced directional pricing structure for empower sticky interfaces
# "Miller, Jensen and Nash"	User-centric bifurcated analyzer for synthesize interactive infrastructures
# Rodriguez PLC	Integrated object-oriented moratorium for aggregate vertical paradigms
# Cardenas Group	Phased stable monitoring for facilitate robust architectures
# Rivera-Flores	Proactive client-server interface for expedite out-of-the-box ROI
# Myers and Sons	Organized upward-trending methodology for facilitate dynamic metrics
# Johnson and Sons	 Public-key empowering methodology for incubate world-class interfaces
# Prince PLC	 Total mission-critical standardization for transition next-generation interfaces
# Thomas and Sons	 Grass-roots next generation Graphical User Interface for utilize front-end action-items
# Morgan-Moreno	 Total tangible architecture for reinvent revolutionary communities
# Henderson Inc	 Stand-alone 6thgeneration encryption for engage cutting-edge e-tailers
# "Jones, Jones and Webb"	 Programmable national firmware for facilitate web-enabled networks
# Hoffman Ltd	 Self-enabling encompassing hardware for empower magnetic platforms
# Bennett Inc	 Diverse systemic extranet for iterate end-to-end channels
# Montgomery PLC	 Extended radical secured line for engage world-class technologies
# "Russell, Cherry and Reynolds"	 Versatile motivating encryption for productize one-to-one interfaces
# Trevino-Wells	 Persistent even-keeled matrix for envisioneer B2B e-services
# "Hicks, Graham and Craig"	 Cloned 6thgeneration attitude for envisioneer dynamic synergies
# "Mahoney, Cooper and Hernandez"	 Organized zero-defect conglomeration for harness impactful web services
# Dean Ltd	 Intuitive local synergy for drive integrated technologies
# "Reese, Lynn and Smith"	 Synergistic 6thgeneration project for maximize real-time methodologies
# Harper-Rubio	 Team-oriented heuristic complexity for embrace enterprise interfaces
# Moreno LLC	 Reverse-engineered web-enabled parallelism for deliver value-added niches
# Moore-Evans	 Devolved responsive instruction set for iterate value-added mindshare
# French-Daniel	 Exclusive motivating monitoring for syndicate strategic paradigms
# Hicks-Hayes	 Phased dedicated paradigm for benchmark front-end e-tailers
# Johnson-Washington	 Organized encompassing definition for syndicate web-enabled niches
# Lee and Sons	 Stand-alone optimal strategy for engineer ubiquitous supply-chains
# Wright PLC	 Profit-focused web-enabled customer loyalty for extend collaborative paradigms
# "Buchanan, Thompson and Frye"	 Sharable 6thgeneration attitude for synthesize back-end initiatives
# Thompson-Roy	 Public-key human-resource policy for reinvent extensible platforms
# "Leach, Schwartz and Adams"	 Monitored eco-centric Local Area Network for streamline cross-media experiences
# Gonzalez-Strickland	 Realigned zero tolerance intranet for iterate collaborative applications
# "Norman, Lindsey and Schmidt"	 Expanded responsive emulation for optimize 24/7 eyeballs
# Gonzalez and Sons	 Robust 3rdgeneration secured line for incubate global solutions
# Mcdonald and Sons	 Self-enabling logistical toolset for embrace user-centric schemas
# Castillo Group	 Configurable grid-enabled toolset for visualize viral systems
# Bradley LLC	 Integrated actuating open architecture for expedite B2B supply-chains
# Miller-Smith	 Multi-channeled human-resource conglomeration for integrate user-centric eyeballs
# Winters Group	 Switchable modular utilization for morph front-end platforms
# "Mitchell, Olson and Alexander"	 Sharable local analyzer for whiteboard cutting-edge eyeballs
# "Turner, Jackson and Santos"	 Inverse demand-driven firmware for deliver e-business relationships
# Morrison and Sons	 Mandatory disintermediate neural-net for envisioneer visionary markets
# Briggs and Sons	 Multi-layered web-enabled paradigm for syndicate cutting-edge applications
# Williams-Phillips	 Ergonomic local synergy for brand user-centric markets
# Garcia LLC	 Re-contextualized zero-defect matrices for expedite customized deliverables
# Jacobson Ltd	 Vision-oriented optimizing monitoring for synthesize next-generation relationships
# Chambers Ltd	 Organic high-level neural-net for repurpose revolutionary eyeballs
# Cruz Inc	Fundamental intangible neural-net for extend visionary solutions
# Barnes Ltd	Face-to-face context-sensitive capability for integrate sticky mindshare
# "Guerrero, Fischer and Reyes"	Intuitive uniform encryption for deploy back-end bandwidth
# "Avila, Morales and Stanton"	Total bifurcated portal for aggregate frictionless synergies
# Walton-Dixon	Progressive modular focus group for visualize B2C ROI
# Boyd Ltd	Universal demand-driven Graphical User Interface for monetize enterprise methodologies
# "Garcia, Myers and Rogers"	Synchronized content-based monitoring for synthesize cutting-edge models
# Oliver-Dickerson	Business-focused executive help-desk for grow cross-platform relationships
# Mayer-Davis	Stand-alone transitional system engine for architect sticky deliverables
# James-Deleon	Secured heuristic focus group for evolve e-business systems
# "Lopez, King and Bowers"	Optional cohesive neural-net for unleash open-source users
# Newton Inc	Synergistic client-driven hierarchy for integrate next-generation mindshare
# Hess LLC	Triple-buffered value-added customer loyalty for deploy sticky systems
# "King, Delgado and Pena"	Robust user-facing standardization for utilize one-to-one interfaces
# Hernandez PLC	User-centric homogeneous application for whiteboard best-of-breed e-tailers
# Hill-Trujillo	Down-sized leadingedge software for productize end-to-end e-tailers
# Cannon LLC	Reduced asymmetric paradigm for integrate global content
# "Bautista, Swanson and Vaughan"	Horizontal multimedia matrix for engage out-of-the-box communities
# Edwards LLC	Reduced intermediate conglomeration for iterate extensible architectures
# "Miller, Sanders and Griffith"	Cross-platform human-resource migration for orchestrate collaborative supply-chains
# Sampson LLC	Re-contextualized content-based hierarchy for aggregate clicks-and-mortar vortals
# "Donovan, Martinez and Houston"	Re-engineered even-keeled framework for transform viral e-services
# Blake-Lee	Reduced bottom-line pricing structure for repurpose end-to-end communities
# Gray Ltd	Managed multimedia framework for incentivize cross-media schemas
# "Dixon, Calderon and Russell"	Intuitive mission-critical protocol for benchmark visionary e-markets
# Haney and Sons	Customer-focused motivating complexity for scale one-to-one initiatives
# Rice and Sons	Enhanced regional infrastructure for monetize value-added e-tailers
# Davis Group	Grass-roots 4thgeneration customer loyalty for engineer frictionless web-readiness
# Cardenas Inc	Cross-group discrete leverage for harness B2B applications
# Haas-Davis	Networked web-enabled software for re-intermediate transparent infrastructures
# Palmer-Williams	Realigned scalable model for utilize interactive e-markets
# "Brown, Chambers and Santos"	Customer-focused multimedia knowledge user for synthesize best-of-breed relationships
# "Smith, Dawson and Brooks"	Business-focused cohesive protocol for orchestrate proactive vortals
# Rodriguez and Sons	Programmable 24hour utilization for enhance front-end e-commerce
# "Patterson, Suarez and Clark"	Synchronized radical Internet solution for envisioneer viral technologies
# Lester-Floyd	Organized intermediate portal for facilitate visionary action-items
# Henderson and Sons	Universal global definition for leverage best-of-breed e-commerce
# "Smith, Manning and Floyd"	Diverse zero-defect application for syndicate impactful channels
# Francis and Sons	Automated 4thgeneration initiative for seize distributed synergies
# Shelton PLC	Inverse leadingedge model for deliver 24/365 content
# Calhoun LLC	Reverse-engineered even-keeled circuit for drive clicks-and-mortar niches
# "Fernandez, George and Hunt"	Virtual heuristic paradigm for benchmark B2B web-readiness
# Johnston-Palmer	Reactive fresh-thinking knowledge user for scale distributed vortals
# "Reyes, Wilson and Lyons"	Operative zero-defect database for mesh viral channels
# Johnson-Miller	Monitored maximized policy for evolve 24/7 communities
# Mclaughlin and Sons	Intuitive exuding encoding for envisioneer customized e-tailers
# "Rogers, Howell and Harvey"	Open-architected disintermediate project for evolve mission-critical methodologies
# Castillo-Schroeder	Vision-oriented national secured line for productize turn-key convergence
# Johnson-Wilson	Grass-roots neutral focus group for optimize granular infrastructures
# Nelson-Brown	Function-based systemic contingency for re-contextualize visionary mindshare
# Davis-Flores	Up-sized object-oriented superstructure for aggregate bricks-and-clicks channels
# Johnson-Osborne	Reverse-engineered bandwidth-monitored extranet for synergize customized metrics
# "Foley, Mitchell and Davis"	Fundamental bifurcated capability for transition B2C architectures
# Sherman-Russo	Cloned bi-directional system engine for seize ubiquitous technologies
# Stevens-Hill	Right-sized human-resource middleware for productize enterprise experiences
# Hughes-Medina	Multi-lateral intermediate encryption for morph viral schemas
# "Beard, Duke and Martin"	Customer-focused web-enabled contingency for cultivate efficient interfaces
# Perry-Fox	Realigned fault-tolerant system engine for re-intermediate cross-media schemas
# Mercado PLC	Re-contextualized multi-state superstructure for utilize scalable content
# "Willis, Martinez and Smith"	Switchable regional website for disintermediate cross-media e-business
# "Vasquez, Garcia and Fletcher"	Exclusive disintermediate algorithm for seize 24/365 web-readiness
# Young-Williams	Multi-tiered local system engine for cultivate turn-key markets
# "Owens, Callahan and Summers"	Synergistic mobile product for brand world-class systems
# Davis LLC	Optional composite paradigm for deploy B2B channels
# Morgan-Franklin	Total fresh-thinking task-force for innovate mission-critical interfaces
# Lang-Frank	Multi-lateral homogeneous solution for facilitate user-centric relationships
# Gross-Jackson	Intuitive local neural-net for streamline customized markets
# Smith LLC	Sharable zero administration definition for monetize integrated portals
# Walker and Sons	Open-architected 3rdgeneration instruction set for generate turn-key relationships
# Moody Group	Configurable multimedia methodology for benchmark e-business models
# Walker-Johnson	User-friendly incremental model for facilitate back-end technologies
# "Flowers, Pollard and Henry"	Up-sized grid-enabled capacity for orchestrate synergistic supply-chains
# "Carter, Parrish and Gonzalez"	Distributed even-keeled contingency for transform enterprise e-business
# Vargas and Sons	Focused modular algorithm for optimize dot-com architectures
# Gonzalez-Long	Monitored mission-critical budgetary management for envisioneer killer partnerships
# Martin LLC	Realigned user-facing capacity for enhance open-source niches
# Casey Inc	Synchronized systematic solution for empower efficient deliverables
# Clark Group	Customer-focused 24/7 portal for transform strategic portals
# "Fox, Adams and Johnson"	User-centric user-facing access for monetize web-enabled systems
# "Davis, Valdez and Keller"	Ameliorated client-server architecture for matrix real-time initiatives
#  Evans Ltd	 Team-oriented upward-trending focus group for redefine synergistic users
# " Martin, Hines and Clark"	 Customizable user-facing solution for harness scalable e-services
# " Lopez, Camacho and Bonilla"	 Object-based asynchronous ability for innovate B2B mindshare
#  Thompson Group	 Synchronized responsive secured line for scale real-time vortals
#  Hughes and Sons	 Customizable local productivity for optimize open-source e-services
#  Patterson-Stewart	 Automated systematic hierarchy for iterate end-to-end models
# " Moore, Diaz and Stevens"	 Devolved empowering complexity for transition virtual metrics
#  Ferrell-Caldwell	 Horizontal mobile utilization for facilitate back-end models
#  Hubbard LLC	 Organic real-time customer loyalty for leverage cutting-edge e-markets
#  Martinez-Glass	 Inverse encompassing project for reinvent transparent applications
#  Newman Ltd	 Adaptive value-added framework for scale cross-platform bandwidth
#  Garrett Inc	 Multi-channeled modular Graphical User Interface for embrace killer convergence
#  Johnson-Gallagher	 Synchronized grid-enabled project for empower visionary eyeballs
#  Pearson-Bass	 Programmable asymmetric open system for deploy interactive users
#  Olson-Zimmerman	 Programmable modular customer loyalty for benchmark enterprise e-business
# " Mccoy, Miller and Schmidt"	 Upgradable hybrid knowledgebase for unleash frictionless web services
#  Roberts Ltd	 Synergistic methodical superstructure for syndicate B2B e-business
#  Williams-Henderson	 Profit-focused fresh-thinking open system for drive open-source content
# " Melendez, Tyler and Hammond"	 Cross-group scalable customer loyalty for incentivize web-enabled action-items
# " Smith, Soto and Simpson"	 Diverse intermediate Graphic Interface for synergize bricks-and-clicks communities
#  Roberts Group	 Organized zero administration concept for re-contextualize back-end e-tailers
#  Bentley Inc	 Synergistic asymmetric standardization for scale enterprise schemas
#  Ellis Group	 Stand-alone grid-enabled encoding for expedite one-to-one networks
#  Cherry-Bentley	 Universal high-level utilization for embrace frictionless mindshare
#  Kim LLC	 Profit-focused dynamic knowledgebase for enhance cross-platform systems
# " Clark, Baker and White"	 User-friendly analyzing product for disintermediate end-to-end architectures
#  Sanders Inc	 Stand-alone bandwidth-monitored budgetary management for enhance intuitive e-services
#  Tran Ltd	 Public-key bottom-line firmware for evolve proactive methodologies
#  Miller Ltd	 Realigned bi-directional process improvement for extend integrated e-markets
#  Diaz Inc	 Switchable optimizing policy for reinvent wireless metrics
# " Winters, Daniels and Mathews"	 Optional homogeneous portal for harness 24/7 web-readiness
# " Taylor, Daniels and Taylor"	 Up-sized global conglomeration for harness strategic deliverables
#  Warner-Morris	 Multi-channeled bandwidth-monitored portal for evolve out-of-the-box content
#  Hurst PLC	 Grass-roots intermediate benchmark for unleash out-of-the-box relationships
#  Stein Group	 Programmable clear-thinking strategy for re-intermediate collaborative e-markets
# " Collins, Mahoney and Taylor"	 Assimilated interactive synergy for evolve bricks-and-clicks architectures
#  Rodriguez Ltd	 Self-enabling encompassing orchestration for facilitate e-business functionalities
#  Williams PLC	 Synchronized background service-desk for syndicate real-time e-markets
#  Hobbs Inc	 Horizontal value-added protocol for engage mission-critical technologies
#  Hernandez-Garcia	 Multi-lateral dynamic focus group for facilitate mission-critical functionalities
#  Rivera-Browning	 Focused asynchronous encryption for e-enable plug-and-play web services
#  Oconnell-Watson	 Proactive regional open system for streamline distributed users
#  Gilmore and Sons	 Function-based global secured line for implement robust interfaces
#  Bates LLC	 Diverse 6thgeneration emulation for aggregate distributed portals
# " Miller, Brewer and Freeman"	 Reverse-engineered clear-thinking budgetary management for visualize viral interfaces
#  Diaz-Parker	 Digitized motivating encryption for transition bleeding-edge relationships
#  Nguyen-Welch	 Multi-lateral clear-thinking middleware for enhance back-end functionalities
#  Garcia LLC	 Customer-focused system-worthy migration for enhance out-of-the-box paradigms
#  Roberts Group	 Assimilated empowering middleware for orchestrate web-enabled networks
#  Mcdonald-Johnson	 Cross-group motivating instruction set for aggregate 24/365 portals
# " Johnston, Crawford and Richardson"	 Virtual system-worthy solution for aggregate B2B solutions
#  Russell-Smith	 Total radical function for enable enterprise relationships
#  Smith-Thompson	 Self-enabling foreground algorithm for revolutionize 24/365 niches
#  Cox and Sons	 Multi-layered bandwidth-monitored superstructure for benchmark 24/365 metrics
# " Duran, Johnson and Stephens"	 Business-focused bottom-line instruction set for streamline world-class e-commerce
#  Rivera-Boyer	 Polarized empowering extranet for drive extensible e-services
#  White-Everett	 Reverse-engineered client-driven functionalities for maximize proactive partnerships
#  Taylor LLC	 Visionary exuding collaboration for engineer frictionless e-commerce
#  Cortez-Mcpherson	 Cross-platform fresh-thinking Graphical User Interface for morph extensible deliverables
# " Allen, Thomas and Martinez"	 Triple-buffered incremental core for syndicate best-of-breed applications
# " Shepherd, Anderson and Hardy"	 Re-engineered stable neural-net for innovate synergistic portals
# " Casey, Johnson and Gray"	 Compatible intermediate forecast for evolve out-of-the-box web services
#  Herrera-Hartman	 Assimilated zero administration customer loyalty for integrate 24/365 action-items
#  Newton Ltd	 Ameliorated leadingedge throughput for utilize 24/7 initiatives
#  Duncan and Sons	 Phased content-based hardware for extend front-end vortals
# " Hicks, Griffin and Juarez"	 Vision-oriented foreground implementation for envisioneer viral web-readiness
#  Wise-Boyd	 Quality-focused even-keeled encryption for e-enable leading-edge e-tailers
#  Warner-Chambers	 Fundamental intermediate help-desk for exploit transparent schemas
# " Castro, Phillips and Fisher"	 Ameliorated context-sensitive project for incubate out-of-the-box web services
#  Cooper Inc	 Integrated clear-thinking groupware for iterate virtual markets
# " Day, Williams and Diaz"	 De-engineered zero tolerance secured line for morph robust models
#  Foster-Dean	 Programmable 4thgeneration conglomeration for unleash value-added info-mediaries
# " Jordan, Rogers and Henson"	 Extended even-keeled capability for embrace holistic content
#  Johnson PLC	 Polarized 5thgeneration policy for incubate world-class interfaces
#  Alexander-Johnson	 Team-oriented regional throughput for repurpose strategic info-mediaries
#  Contreras-Hernandez	 Proactive zero-defect middleware for monetize holistic bandwidth
#  Cummings-Anderson	 Focused upward-trending budgetary management for deliver next-generation infrastructures
#  Cardenas Inc	 Switchable non-volatile support for grow transparent e-business
#  Mcgee Inc	 Re-engineered client-server product for target cross-platform users
#  Jones-Summers	 Visionary bi-directional structure for strategize 24/365 infrastructures
#  Levy LLC	 Optimized system-worthy workforce for harness bleeding-edge schemas
#  Reed Ltd	 Compatible impactful core for redefine dot-com networks
#  Owens Ltd	 Monitored actuating migration for reinvent out-of-the-box bandwidth
#  King Inc	 Face-to-face composite firmware for productize frictionless users
# " Lang, Brown and Rodriguez"	 Inverse incremental emulation for visualize cutting-edge ROI
#  Joseph-Warren	 Decentralized explicit approach for streamline one-to-one infrastructures
#  Bryant LLC	 Cross-platform explicit hardware for integrate world-class systems
# " Meadows, Vazquez and Martin"	 Re-contextualized value-added portal for iterate back-end bandwidth
# " Pugh, Lewis and Williams"	 Exclusive analyzing intranet for evolve global portals
#  Cole Inc	 Synergized composite capacity for integrate value-added functionalities
# " Walton, Webb and Watkins"	 Front-line value-added circuit for architect synergistic models
#  Ali-Cain	 Extended systematic knowledge user for re-contextualize real-time platforms
#  Robles-Kerr	 Configurable fresh-thinking Graphical User Interface for transform e-business models
#  Simmons and Sons	 Visionary explicit model for cultivate value-added info-mediaries
#  Spencer-Black	 Realigned zero-defect ability for mesh end-to-end technologies
#  Bowman-Romero	 De-engineered maximized application for target one-to-one communities
# " Moore, Franklin and Mcgee"	 Networked leadingedge collaboration for repurpose visionary deliverables
#  Ross PLC	 Reverse-engineered local alliance for re-contextualize holistic networks
#  Davis-Hernandez	 Triple-buffered methodical synergy for re-intermediate back-end channels
#  Jones-Flores	 Reduced upward-trending portal for streamline collaborative e-commerce
#  Carlson-Ramsey	 Optimized leadingedge protocol for whiteboard plug-and-play networks
#  Solomon Ltd	 User-friendly needs-based hub for drive real-time e-commerce
#  Marshall Inc	 Object-based cohesive circuit for matrix turn-key architectures
#  Graham LLC	 Optimized encompassing toolset for generate scalable paradigms
#  Cooper-Guerrero	 Down-sized exuding hardware for syndicate proactive schemas
#  Turner Group	 Phased eco-centric open architecture for exploit one-to-one content
#  Romero Group	 Profit-focused asynchronous structure for monetize bleeding-edge users
#  Taylor Ltd	 Reactive eco-centric solution for incentivize impactful bandwidth
#  Anderson Group	 Configurable intermediate info-mediaries for empower virtual models
# " Mendoza, Cooper and Davis"	 Assimilated needs-based concept for embrace dynamic supply-chains
# " Jones, Chaney and Santana"	 Optional composite info-mediaries for engineer dot-com e-tailers
# " Murillo, Johnson and Garrett"	 Polarized impactful open architecture for integrate plug-and-play e-tailers
#  Diaz-Ross	 Configurable explicit customer loyalty for brand dynamic models
#  Delgado Group	 Synergized full-range framework for exploit B2B web-readiness
#  Butler and Sons	 Fundamental contextually-based challenge for embrace revolutionary systems
#  Reyes PLC	 Customizable methodical migration for unleash best-of-breed convergence
#  Mcintyre Ltd	 Realigned actuating data-warehouse for brand proactive communities
#  Butler Group	 Face-to-face needs-based secured line for scale strategic users
# " Vance, Patel and Winters"	 Synergized 4thgeneration instruction set for unleash cross-media systems
#  Willis and Sons	 Team-oriented holistic neural-net for productize killer partnerships
#  Davis-Hernandez	 Open-architected multi-tasking attitude for leverage B2B supply-chains
#  Shepard and Sons	 Profit-focused homogeneous access for morph virtual methodologies
#  Campbell Inc	 Phased clear-thinking firmware for redefine visionary infrastructures
#  Murphy and Sons	 Extended stable parallelism for drive back-end e-commerce
# " Casey, Perez and Myers"	 Optimized intermediate policy for facilitate enterprise technologies
#  Burns Inc	 Configurable analyzing paradigm for aggregate enterprise infrastructures
#  Pennington and Sons'	Proactive neutral definition for utilize wireless deliverables'
# Perry and Sons'	Realigned zero-defect conglomeration for generate back-end portals'
# "Peterson, Hernandez and Snyder'"	Ergonomic 5thgeneration solution for orchestrate e-business niches'
#  Barnes-Griffin'	('Switchable eco-centric throughput for revolutionize plug-and-play ' 'e-business')
# " Burton, Kelly and Deleon'"	Business-focused motivating adapter for innovate killer e-commerce'
#  Bray Inc'	Synchronized directional attitude for syndicate next-generation ROI'
#  Edwards-Moyer'	('Fully-configurable context-sensitive throughput for harness global ' 'deliverables')
#  Estrada-Harvey'	Balanced local hub for engineer granular mindshare'
# " Oconnor, Scott and Harmon'"	Adaptive grid-enabled ability for deploy collaborative architectures'
#  Holmes LLC'	Robust homogeneous forecast for re-intermediate vertical interfaces'
#  Curry-Jones'	Balanced responsive superstructure for cultivate e-business models'
#  Hayden-Rogers'	Horizontal multi-state ability for matrix end-to-end eyeballs'
#  Stanton-Myers'	('Exclusive tangible approach for re-intermediate efficient ' 'partnerships')
# " Castaneda, Myers and Ray'"	Persevering 24hour strategy for streamline user-centric relationships'
#  Williams Group'	Optimized tangible installation for embrace distributed synergies'
#  Wells-Allen'	User-centric maximized hierarchy for unleash one-to-one content'
#  Hudson Group'	('Cross-platform background Graphic Interface for re-contextualize ' '24/7 applications')
#  Grant-Nichols'	Automated background frame for evolve best-of-breed paradigms'
#  Pratt-Hoffman'	Multi-lateral encompassing contingency for enable proactive vortals'
# " Coleman, Miller and Baldwin'"	('Progressive cohesive infrastructure for innovate open-source ' 'functionalities')
#  Hayes-Hall'	Automated content-based paradigm for generate real-time applications'
#  Ramos and Sons'	Re-engineered dedicated paradigm for cultivate intuitive users'
#  Ball and Sons'	('Quality-focused asymmetric toolset for harness bleeding-edge ' 'platforms')
#  Reed-Wolfe'	Optional 24/7 implementation for enable sticky applications'
# " Williams, Gomez and Butler'"	('Polarized multimedia Graphical User Interface for morph distributed ' 'initiatives')
# " Le, Contreras and Campbell'"	Horizontal bi-directional policy for benchmark granular experiences'
#  Estes-Navarro'	User-centric stable capacity for revolutionize B2C functionalities'
#  Calderon-Cooke'	Networked didactic adapter for synergize sexy technologies'
#  Morales LLC'	Networked mobile moratorium for enhance viral niches'
# " Nunez, Miller and Rhodes'"	('Business-focused object-oriented toolset for envisioneer efficient ' 'users')
#  Weiss Group'	('Multi-channeled impactful infrastructure for evolve holistic ' 'web-readiness')
# " Williams, Wilson and Morris'"	Fundamental maximized initiative for harness efficient e-commerce'
#  Vasquez-Silva'	Compatible national solution for aggregate dynamic mindshare'
#  Lee Group'	('Multi-channeled needs-based help-desk for evolve open-source ' 'e-business')
# " Dominguez, Jackson and Clark'"	('Proactive directional encryption for unleash mission-critical ' 'mindshare')
# " West, Melendez and Edwards,"	Synergized heuristic algorithm for evolve plug-and-play networks
# "patel, Chapman and Chapman,"	Universal client-server customer loyalty for embrace distributed functionalities
# " Kim, Schultz and Johnson,"	Visionary asymmetric frame for syndicate collaborative channels
# " Woods, Campbell and Ramos,"	persistent systemic solution for embrace turn-key schemas
# " Sanders-Hernandez,"	progressive local system engine for drive scalable technologies
# " Chavez-Short,"	progressive local database for seize e-business content
# " Wilson-Brown,"	Enterprise-wide analyzing architecture for disintermediate cross-media eyeballs
# " Tyler-Gill,"	De-engineered interactive function for architect 24/7 supply-chains
# " Bernard, Wolf and Nicholson,"	Cross-platform zero tolerance customer loyalty for innovate value-added e-markets
# " Fernandez LLC,"	Enhanced even-keeled encoding for utilize value-added applications
# " Robinson, Kelly and Gonzalez,"	User-centric 3rdgeneration contingency for facilitate mission-critical web-readiness
# " Wilson, Bryant and Morrison,"	progressive executive hub for leverage front-end architectures
# " Arnold, parker and Fischer,"	Automated value-added strategy for cultivate granular relationships
# "Peck, Kelley and Gordon,"	phased exuding service-desk for revolutionize user-centric architectures
# " Aguilar LLC,"	Customer-focused hybrid database for optimize e-business models
# " Tate-Smith,"	persevering methodical data-warehouse for utilize extensible schemas
# " Woods Inc,"	Distributed well-modulated utilization for morph cross-platform content
# " Rice, Holden and Gomez,"	Switchable methodical budgetary management for expedite proactive networks
# " Clark Ltd,"	Business-focused fault-tolerant initiative for visualize dot-com e-services
# " Fritz Group,"	Robust directional functionalities for morph open-source users
# " Bird, arker and Cole,"	Future-proofed clear-thinking approach for harness B2B web-readiness
# " Smith, Richardson and Johnson,"	Configurable fault-tolerant infrastructure for transition collaborative communities
# " Cox-Sandoval,"	Reactive optimal solution for generate e-business metrics
# " Baker-Johnson,"	Horizontal grid-enabled function for seize global networks
# " Andrews Group,"	Total eco-centric interface for whiteboard killer mindshare
# " Taylor Ltd,"	progressive mobile info-mediaries for benchmark bleeding-edge niches
# " Dawson, Cardenas and Flores,"	phased local access for integrate B2C web-readiness
# " Mclean and Sons,"	Open-architected modular ability for integrate turn-key methodologies
# " Turner-Nelson,"	programmable local website for visualize enterprise supply-chains
# " Hall, Jackson and Robertson,"	Down-sized modular website for synthesize virtual ROI
# " Weiss-Hernandez,"	Customizable background help-desk for productize collaborative metrics
# " Merritt Ltd,"	Sharable maximized moratorium for empower cutting-edge niches
# " Norton, Santana and Evans,"	Automated reciprocal service-desk for unleash virtual e-commerce
# " Wilson-Hernandez,"	Open-architected bottom-line conglomeration for harness end-to-end info-mediaries
# " Martinez-Miles,"	Reactive context-sensitive leverage for optimize e-business supply-chains
# " Tran-Morris,"	Operative exuding neural-net for matrix value-added vortals
# " Cox, Livingston and Davis,"	Total non-volatile firmware for grow world-class networks
# " Zhang-Hill,"	Ergonomic directional hub for revolutionize end-to-end models
# " Anderson LLC,"	Digitized analyzing secured line for synthesize efficient e-tailers
# " Allen, Evans and atel,"	Front-line upward-trending throughput for e-enable viral infrastructures
# " Fleming Inc,"	Implemented intermediate matrices for orchestrate magnetic experiences
# " Ferguson, Brown and Floyd,"	Devolved zero administration middleware for deploy transparent info-mediaries
# " Wong, Williams and Moreno,"	Quality-focused tangible software for exploit world-class applications
#  Phillips Group	 Innovative scalable artificial intelligence for orchestrate virtual models
# "Allen, Sharp and Nguyen"	Persevering local framework for facilitate extensible e-business
#  Lambert-Philps	profound secondary toolset for generate synergistic applications
# " Hunter, Harris and Tyler"	 Expanded secondary open system for drive integrated platforms
# "Green, Holland and Bennett"	 Enhanced clear-thinking extranet for visualize killer e-markets
#  Green Inc	 Triple-buffered human-resource knowledge user for cultivate dot-com action-items
# " Small, Huffman and Riley"	 Team-oriented analyzing collaboration for enhance efficient models
# " Hall, Heath and Perez'"	('Managed 3rdgeneration artificial intelligence for optimize seamless ' 'ROI')
# Alexander-Moore	Grass-roots secondary benchmark for optimize user-centric deliverables
# "Gregory, Dawson and Davila"	Synergized secondary task-force for facilitate visionary web services
# "Franklin, Flynn and Bell"	Pre-emptive secondary projection for re-contextualize sticky e-markets
# " Johnson, Morgan and Lopez"	 Streamlined secondary strategy for benchmark web-enabled e-business
#  Grimes Inc	 De-engineered secondary support for visualize robust architectures
#  Flores Inc'	Self-enabling secondary framework for target extensible e-services'
# Smith-Russo	Quality-focused didactic portal for evolve robust channels
# Bates-Johnson	Distributed didactic portal for mesh integrated synergies
# Patrick Ltd	Extended didactic workforce for matrix cross-media solutions
# "Wolfe, Martinez and Alvarado"	 Vision-oriented didactic help-desk for unleash web-enabled users
#  Stevens-King	 Reduced didactic interface for grow next-generation e-business
# " Craig, Weber and Wolfe,"	Down-sized didactic implementation for grow transparent e-services
# Wright LLC	Triple-buffered 6thgeneration artificial intelligence for grow 24/7 vortals
# " Coffey, Barron and Morse"	 Front-line regional artificial intelligence for synthesize turn-key eyeballs
#  Stevenson-Copeland	 Future-proofed multi-state artificial intelligence for incentivize 24/365 platforms
#  Marshall LLC	 Monitored stable artificial intelligence for drive front-end schemas
# " Johnson Ltd,"	Synchronized clear-thinking artificial intelligence for cultivate efficient interfaces
# " Fleming Ltd,"	Compatible maximized artificial intelligence for orchestrate sticky ROI
